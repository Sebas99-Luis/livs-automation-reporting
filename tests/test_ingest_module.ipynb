# %%
import sys
sys.path.append(r"C:\Users\info\Documents\NORRDATA\Proyectos\livs-automation-reporting\src")

# %%
sys.path
# Out:
# ['C:\\Users\\info\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip',
#  'C:\\Users\\info\\AppData\\Local\\Programs\\Python\\Python311\\DLLs',
#  'C:\\Users\\info\\AppData\\Local\\Programs\\Python\\Python311\\Lib',
#  'C:\\Users\\info\\AppData\\Local\\Programs\\Python\\Python311',
#  'C:\\Users\\info\\Documents\\NORRDATA\\Proyectos\\livs-automation-reporting\\.venv',
#  '',
#  'C:\\Users\\info\\Documents\\NORRDATA\\Proyectos\\livs-automation-reporting\\.venv\\Lib\\site-packages',
#  'C:\\Users\\info\\Documents\\NORRDATA\\Proyectos\\livs-automation-reporting\\src',
#  'C:\\Users\\info\\Documents\\NORRDATA\\Proyectos\\livs-automation-reporting\\src']

# %%
from ingest.detect_files import get_incoming_files
from ingest.read_csv import read_csv_file

# %%
files = get_incoming_files()
files
# Out:
# ['C:\\Users\\info\\Documents\\NORRDATA\\Proyectos\\livs-automation-reporting\\data\\incoming\\sales_2026_01_12.csv']

# %%
from ingest.read_csv import read_csv_file

file_path = files[0]  # el archivo que detectaste
df, missing = read_csv_file(file_path)

df, missing
# Out:
# (               sale_id   sale_date          product_name       category  \
#  0     S-20260112-00832  2026-01-12          Tonfisk burk         Pantry
#  1     S-20260112-00125  2026-01-12               Bananer        Produce
#  2     S-20260112-01432  12/01/2026      Krossade tomater         Pantry
#  3     S-20260112-01614  2026-01-12           Ägg 12-pack          Dairy
#  4     S-20260112-00701  2026-01-12              Mjölk 1L          Dairy
#  ...                ...         ...                   ...            ...
#  2654  S-20260112-01639  2026-01-12              Tandkräm  Personal Care
#  2655  S-20260112-01096  2026-01-12             Smör 500g          Dairy
#  2656  S-20260112-01131  12/01/2026           Ägg 12-pack          Dairy
#  2657  S-20260112-01295  12/01/2026  Toalettpapper 8-pack      Household
#  2658  S-20260112-00861  12/01/2026               Schampo  Personal Care
#
#        quantity  unit_price  total_amount payment_method     status
#  0            1        24.9          24.9           card  completed
#  1            1        29.9          29.9          swish  completed
#  2            1        14.9          14.9           card  completed
#  3            1        39.9          39.9           card   refunded
#  4            1        18.9          18.9           card  completed
#  ...        ...         ...           ...            ...        ...
#  2654         5        28.4         142.0          swish  completed
#  2655         1        49.9          49.9           card  completed
#  2656         2        39.9          79.8           card  completed
#  2657         3        59.9         179.7          swish  completed
#  2658         2        49.9          99.8           card  completed
#
#  [2659 rows x 9 columns],
#  None)

# %%
df.head()
# Out:
#             sale_id   sale_date      product_name category  quantity  \
# 0  S-20260112-00832  2026-01-12      Tonfisk burk   Pantry         1
# 1  S-20260112-00125  2026-01-12           Bananer  Produce         1
# 2  S-20260112-01432  12/01/2026  Krossade tomater   Pantry         1
# 3  S-20260112-01614  2026-01-12       Ägg 12-pack    Dairy         1
# 4  S-20260112-00701  2026-01-12          Mjölk 1L    Dairy         1
#
#    unit_price  total_amount payment_method     status
# 0        24.9          24.9           card  completed
# 1        29.9          29.9          swish  completed
# 2        14.9          14.9           card  completed
# 3        39.9          39.9           card   refunded
# 4        18.9          18.9           card  completed
